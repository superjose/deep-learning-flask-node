# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
NUM_WORDS = 10_000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words = NUM_WORDS)

# %%
def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    
    for i, word_indices in enumerate(sequences):
            results[i, word_indices] = 1.0 # Set Specific Indices of results[i] to 1s
    return results

train_data = multi_hot_sequences(train_data, dimension = NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension = NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
# Creating a baseline model

baseline_model = keras.Sequential([
    keras.layers.Dense(16, activation = tf.nn.relu, input_shape = (NUM_WORDS, )),
    keras.layers.Dense(16, activation = tf.nn.relu),
    keras.layers.Dense(1, activation = tf.nn.sigmoid)
])

baseline_model.compile(optimizer = 'adam',
                       loss = 'binary_crossentropy',
                       metrics = ['accuracy', 'binary_crossentropy']
                      )

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, train_labels, 
                                     epochs = 20,
                                     batch_size = 512,
                                     validation_data = (test_data, test_labels),
                                     verbose = 2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 15s - loss: 0.4530 - acc: 0.8140 - binary_crossentropy: 0.4530 - val_loss: 0.3166 - val_acc: 0.8782 - val_binary_crossentropy: 0.3166
# Epoch 2/20
#  - 15s - loss: 0.2328 - acc: 0.9151 - binary_crossentropy: 0.2328 - val_loss: 0.2841 - val_acc: 0.8874 - val_binary_crossentropy: 0.2841
# Epoch 3/20
#  - 12s - loss: 0.1727 - acc: 0.9390 - binary_crossentropy: 0.1727 - val_loss: 0.2937 - val_acc: 0.8834 - val_binary_crossentropy: 0.2937
# Epoch 4/20
#  - 6s - loss: 0.1378 - acc: 0.9523 - binary_crossentropy: 0.1378 - val_loss: 0.3223 - val_acc: 0.8781 - val_binary_crossentropy: 0.3223
# Epoch 5/20
#  - 7s - loss: 0.1142 - acc: 0.9615 - binary_crossentropy: 0.1142 - val_loss: 0.3519 - val_acc: 0.8718 - val_binary_crossentropy: 0.3519
# Epoch 6/20
#  - 7s - loss: 0.0935 - acc: 0.9708 - binary_crossentropy: 0.0935 - val_loss: 0.3864 - val_acc: 0.8690 - val_binary_crossentropy: 0.3864
# Epoch 7/20
#  - 9s - loss: 0.0767 - acc: 0.9780 - binary_crossentropy: 0.0767 - val_loss: 0.4398 - val_acc: 0.8614 - val_binary_crossentropy: 0.4398
# Epoch 8/20
#  - 9s - loss: 0.0637 - acc: 0.9824 - binary_crossentropy: 0.0637 - val_loss: 0.4721 - val_acc: 0.8610 - val_binary_crossentropy: 0.4721
# Epoch 9/20
#  - 8s - loss: 0.0520 - acc: 0.9874 - binary_crossentropy: 0.0520 - val_loss: 0.5147 - val_acc: 0.8587 - val_binary_crossentropy: 0.5147
# Epoch 10/20
#  - 8s - loss: 0.0423 - acc: 0.9911 - binary_crossentropy: 0.0423 - val_loss: 0.5660 - val_acc: 0.8550 - val_binary_crossentropy: 0.5660
# Epoch 11/20
#  - 6s - loss: 0.0355 - acc: 0.9925 - binary_crossentropy: 0.0355 - val_loss: 0.6101 - val_acc: 0.8539 - val_binary_crossentropy: 0.6101
# Epoch 12/20
#  - 6s - loss: 0.0265 - acc: 0.9956 - binary_crossentropy: 0.0265 - val_loss: 0.6562 - val_acc: 0.8534 - val_binary_crossentropy: 0.6562
# Epoch 13/20
#  - 7s - loss: 0.0196 - acc: 0.9975 - binary_crossentropy: 0.0196 - val_loss: 0.6998 - val_acc: 0.8514 - val_binary_crossentropy: 0.6998
# Epoch 14/20
#  - 6s - loss: 0.0143 - acc: 0.9988 - binary_crossentropy: 0.0143 - val_loss: 0.7390 - val_acc: 0.8501 - val_binary_crossentropy: 0.7390
# Epoch 15/20
#  - 6s - loss: 0.0104 - acc: 0.9996 - binary_crossentropy: 0.0104 - val_loss: 0.7798 - val_acc: 0.8498 - val_binary_crossentropy: 0.7798
# Epoch 16/20
#  - 9s - loss: 0.0078 - acc: 0.9998 - binary_crossentropy: 0.0078 - val_loss: 0.8099 - val_acc: 0.8496 - val_binary_crossentropy: 0.8099
# Epoch 17/20
#  - 9s - loss: 0.0060 - acc: 0.9999 - binary_crossentropy: 0.0060 - val_loss: 0.8394 - val_acc: 0.8495 - val_binary_crossentropy: 0.8394
# Epoch 18/20
#  - 9s - loss: 0.0048 - acc: 0.9999 - binary_crossentropy: 0.0048 - val_loss: 0.8680 - val_acc: 0.8484 - val_binary_crossentropy: 0.8680
# Epoch 19/20
#  - 9s - loss: 0.0039 - acc: 0.9999 - binary_crossentropy: 0.0039 - val_loss: 0.8914 - val_acc: 0.8491 - val_binary_crossentropy: 0.8914
# Epoch 20/20
#  - 10s - loss: 0.0032 - acc: 1.0000 - binary_crossentropy: 0.0032 - val_loss: 0.9149 - val_acc: 0.8484 - val_binary_crossentropy: 0.9149

# %%
# Smaller Model:
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation = tf.nn.relu, input_shape=(NUM_WORDS, )),
    keras.layers.Dense(4, activation = tf.nn.relu),
    keras.layers.Dense(1, activation = tf.nn.sigmoid)
])

smaller_model.compile(optimizer = 'adam', 
                     loss = 'binary_crossentropy',
                     metrics = ['accuracy', 'binary_crossentropy'])

smaller_model.summary()


smaller_history = smaller_model.fit(train_data, 
                                   train_labels,
                                   epochs = 20,
                                   batch_size = 512,
                                   validation_data = (test_data, test_labels),
                                   verbose = 2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 15s - loss: 0.5976 - acc: 0.7887 - binary_crossentropy: 0.5976 - val_loss: 0.5031 - val_acc: 0.8607 - val_binary_crossentropy: 0.5031
# Epoch 2/20
#  - 13s - loss: 0.4132 - acc: 0.8888 - binary_crossentropy: 0.4132 - val_loss: 0.3859 - val_acc: 0.8750 - val_binary_crossentropy: 0.3859
# Epoch 3/20
#  - 5s - loss: 0.3126 - acc: 0.9069 - binary_crossentropy: 0.3126 - val_loss: 0.3289 - val_acc: 0.8845 - val_binary_crossentropy: 0.3289
# Epoch 4/20
#  - 5s - loss: 0.2560 - acc: 0.9209 - binary_crossentropy: 0.2560 - val_loss: 0.3020 - val_acc: 0.8868 - val_binary_crossentropy: 0.3020
# Epoch 5/20
#  - 5s - loss: 0.2203 - acc: 0.9299 - binary_crossentropy: 0.2203 - val_loss: 0.2897 - val_acc: 0.8876 - val_binary_crossentropy: 0.2897
# Epoch 6/20
#  - 8s - loss: 0.1947 - acc: 0.9372 - binary_crossentropy: 0.1947 - val_loss: 0.2837 - val_acc: 0.8890 - val_binary_crossentropy: 0.2837
# Epoch 7/20
#  - 8s - loss: 0.1750 - acc: 0.9446 - binary_crossentropy: 0.1750 - val_loss: 0.2834 - val_acc: 0.8875 - val_binary_crossentropy: 0.2834
# Epoch 8/20
#  - 7s - loss: 0.1590 - acc: 0.9494 - binary_crossentropy: 0.1590 - val_loss: 0.2867 - val_acc: 0.8860 - val_binary_crossentropy: 0.2867
# Epoch 9/20
#  - 9s - loss: 0.1466 - acc: 0.9532 - binary_crossentropy: 0.1466 - val_loss: 0.2915 - val_acc: 0.8846 - val_binary_crossentropy: 0.2915
# Epoch 10/20
#  - 6s - loss: 0.1343 - acc: 0.9577 - binary_crossentropy: 0.1343 - val_loss: 0.3016 - val_acc: 0.8804 - val_binary_crossentropy: 0.3016
# Epoch 11/20
#  - 5s - loss: 0.1243 - acc: 0.9624 - binary_crossentropy: 0.1243 - val_loss: 0.3076 - val_acc: 0.8808 - val_binary_crossentropy: 0.3076
# Epoch 12/20
#  - 6s - loss: 0.1152 - acc: 0.9653 - binary_crossentropy: 0.1152 - val_loss: 0.3197 - val_acc: 0.8768 - val_binary_crossentropy: 0.3197
# Epoch 13/20
#  - 5s - loss: 0.1070 - acc: 0.9690 - binary_crossentropy: 0.1070 - val_loss: 0.3264 - val_acc: 0.8765 - val_binary_crossentropy: 0.3264
# Epoch 14/20
#  - 6s - loss: 0.0999 - acc: 0.9716 - binary_crossentropy: 0.0999 - val_loss: 0.3377 - val_acc: 0.8744 - val_binary_crossentropy: 0.3377
# Epoch 15/20
#  - 5s - loss: 0.0929 - acc: 0.9736 - binary_crossentropy: 0.0929 - val_loss: 0.3494 - val_acc: 0.8732 - val_binary_crossentropy: 0.3494
# Epoch 16/20
#  - 6s - loss: 0.0867 - acc: 0.9768 - binary_crossentropy: 0.0867 - val_loss: 0.3614 - val_acc: 0.8722 - val_binary_crossentropy: 0.3614
# Epoch 17/20
#  - 6s - loss: 0.0811 - acc: 0.9793 - binary_crossentropy: 0.0811 - val_loss: 0.3761 - val_acc: 0.8692 - val_binary_crossentropy: 0.3761
# Epoch 18/20
#  - 6s - loss: 0.0756 - acc: 0.9820 - binary_crossentropy: 0.0756 - val_loss: 0.3913 - val_acc: 0.8680 - val_binary_crossentropy: 0.3913
# Epoch 19/20
#  - 5s - loss: 0.0706 - acc: 0.9837 - binary_crossentropy: 0.0706 - val_loss: 0.4024 - val_acc: 0.8675 - val_binary_crossentropy: 0.4024
# Epoch 20/20
#  - 5s - loss: 0.0658 - acc: 0.9854 - binary_crossentropy: 0.0658 - val_loss: 0.4172 - val_acc: 0.8662 - val_binary_crossentropy: 0.4172

# %%
bigger_model = keras.Sequential([
    keras.layers.Dense(512, activation = tf.nn.relu, input_shape = (NUM_WORDS, )),
    keras.layers.Dense(512, activation = tf.nn.relu),
    keras.layers.Dense(1, activation = tf.nn.sigmoid)
])

bigger_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy', 'binary_crossentropy'])
bigger_model.summary()

bigger_history = bigger_model.fit(train_data, train_labels, epochs = 20, batch_size = 512, 
                                  validation_data = (test_data, test_labels),
                                  verbose = 2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 15s - loss: 0.3454 - acc: 0.8504 - binary_crossentropy: 0.3454 - val_loss: 0.2944 - val_acc: 0.8810 - val_binary_crossentropy: 0.2944
# Epoch 2/20
#  - 14s - loss: 0.1445 - acc: 0.9468 - binary_crossentropy: 0.1445 - val_loss: 0.3537 - val_acc: 0.8653 - val_binary_crossentropy: 0.3537
# Epoch 3/20
#  - 13s - loss: 0.0546 - acc: 0.9838 - binary_crossentropy: 0.0546 - val_loss: 0.4135 - val_acc: 0.8676 - val_binary_crossentropy: 0.4135
# Epoch 4/20
#  - 13s - loss: 0.0101 - acc: 0.9985 - binary_crossentropy: 0.0101 - val_loss: 0.5768 - val_acc: 0.8699 - val_binary_crossentropy: 0.5768
# Epoch 5/20
#  - 13s - loss: 0.0011 - acc: 1.0000 - binary_crossentropy: 0.0011 - val_loss: 0.6664 - val_acc: 0.8706 - val_binary_crossentropy: 0.6664
# Epoch 6/20
#  - 13s - loss: 5.3218e-04 - acc: 1.0000 - binary_crossentropy: 5.3218e-04 - val_loss: 0.7065 - val_acc: 0.8703 - val_binary_crossentropy: 0.7065
# Epoch 7/20
#  - 14s - loss: 5.4403e-04 - acc: 1.0000 - binary_crossentropy: 5.4403e-04 - val_loss: 0.7288 - val_acc: 0.8716 - val_binary_crossentropy: 0.7288
# Epoch 8/20
#  - 13s - loss: 2.1513e-04 - acc: 1.0000 - binary_crossentropy: 2.1513e-04 - val_loss: 0.7654 - val_acc: 0.8683 - val_binary_crossentropy: 0.7654
# Epoch 9/20
#  - 13s - loss: 1.0227e-04 - acc: 1.0000 - binary_crossentropy: 1.0227e-04 - val_loss: 0.7703 - val_acc: 0.8710 - val_binary_crossentropy: 0.7703
# Epoch 10/20
#  - 13s - loss: 7.1770e-05 - acc: 1.0000 - binary_crossentropy: 7.1770e-05 - val_loss: 0.7861 - val_acc: 0.8713 - val_binary_crossentropy: 0.7861
# Epoch 11/20
#  - 14s - loss: 5.5815e-05 - acc: 1.0000 - binary_crossentropy: 5.5815e-05 - val_loss: 0.8014 - val_acc: 0.8711 - val_binary_crossentropy: 0.8014
# Epoch 12/20
#  - 13s - loss: 4.4851e-05 - acc: 1.0000 - binary_crossentropy: 4.4851e-05 - val_loss: 0.8140 - val_acc: 0.8713 - val_binary_crossentropy: 0.8140
# Epoch 13/20
#  - 13s - loss: 3.6885e-05 - acc: 1.0000 - binary_crossentropy: 3.6885e-05 - val_loss: 0.8255 - val_acc: 0.8712 - val_binary_crossentropy: 0.8255
# Epoch 14/20
#  - 13s - loss: 3.0846e-05 - acc: 1.0000 - binary_crossentropy: 3.0846e-05 - val_loss: 0.8360 - val_acc: 0.8711 - val_binary_crossentropy: 0.8360
# Epoch 15/20
#  - 13s - loss: 2.6101e-05 - acc: 1.0000 - binary_crossentropy: 2.6101e-05 - val_loss: 0.8459 - val_acc: 0.8713 - val_binary_crossentropy: 0.8459
# Epoch 16/20
#  - 13s - loss: 2.2342e-05 - acc: 1.0000 - binary_crossentropy: 2.2342e-05 - val_loss: 0.8544 - val_acc: 0.8714 - val_binary_crossentropy: 0.8544
# Epoch 17/20
#  - 13s - loss: 1.9288e-05 - acc: 1.0000 - binary_crossentropy: 1.9288e-05 - val_loss: 0.8638 - val_acc: 0.8712 - val_binary_crossentropy: 0.8638
# Epoch 18/20
#  - 13s - loss: 1.6805e-05 - acc: 1.0000 - binary_crossentropy: 1.6805e-05 - val_loss: 0.8711 - val_acc: 0.8712 - val_binary_crossentropy: 0.8711
# Epoch 19/20
#  - 13s - loss: 1.4698e-05 - acc: 1.0000 - binary_crossentropy: 1.4698e-05 - val_loss: 0.8784 - val_acc: 0.8712 - val_binary_crossentropy: 0.8784
# Epoch 20/20
#  - 13s - loss: 1.2963e-05 - acc: 1.0000 - binary_crossentropy: 1.2963e-05 - val_loss: 0.8861 - val_acc: 0.8715 - val_binary_crossentropy: 0.8861

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize= (16, 10))
    
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                      '--', label = name.title() + ' Val')
        plt.plot(history.epoch, history.history[key], color = val[0].get_color(),
                label = name.title() + ' Train')
        
    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_', ' ').title())
    plt.legend()
    
    plt.xlim([0, max(history.epoch)])
    
plot_history([('basline', baseline_history),
             ('smaller', smaller_history),
             ('bigger', bigger_history)])

# %%
# Regularized Params:

l2_model = keras.Sequential([
    keras.layers.Dense(16, kernel_regularizer = keras.regularizers.l2(0.001),
                      activation = tf.nn.relu, input_shape= (NUM_WORDS, )),
    keras.layers.Dense(16, kernel_regularizer = keras.regularizers.l2(0.001),
                      activation = tf.nn.relu),
    keras.layers.Dense(1, activation = tf.nn.sigmoid)
])
    
l2_model.compile(optimizer = 'adam', loss='binary_crossentropy',
                 metrics = ['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels, epochs = 20, batch_size = 512, 
                                validation_data = (test_data, test_labels),
                               verbose = 2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 11s - loss: 0.5386 - acc: 0.7983 - binary_crossentropy: 0.4977 - val_loss: 0.3840 - val_acc: 0.8744 - val_binary_crossentropy: 0.3413
# Epoch 2/20
#  - 7s - loss: 0.3049 - acc: 0.9097 - binary_crossentropy: 0.2576 - val_loss: 0.3357 - val_acc: 0.8864 - val_binary_crossentropy: 0.2849
# Epoch 3/20
#  - 5s - loss: 0.2532 - acc: 0.9296 - binary_crossentropy: 0.1997 - val_loss: 0.3396 - val_acc: 0.8861 - val_binary_crossentropy: 0.2840
# Epoch 4/20
#  - 6s - loss: 0.2280 - acc: 0.9413 - binary_crossentropy: 0.1707 - val_loss: 0.3545 - val_acc: 0.8817 - val_binary_crossentropy: 0.2960
# Epoch 5/20
#  - 5s - loss: 0.2145 - acc: 0.9476 - binary_crossentropy: 0.1543 - val_loss: 0.3662 - val_acc: 0.8792 - val_binary_crossentropy: 0.3049
# Epoch 6/20
#  - 5s - loss: 0.1999 - acc: 0.9534 - binary_crossentropy: 0.1379 - val_loss: 0.3823 - val_acc: 0.8759 - val_binary_crossentropy: 0.3197
# Epoch 7/20
#  - 4s - loss: 0.1912 - acc: 0.9579 - binary_crossentropy: 0.1273 - val_loss: 0.3968 - val_acc: 0.8728 - val_binary_crossentropy: 0.3318
# Epoch 8/20
#  - 5s - loss: 0.1811 - acc: 0.9631 - binary_crossentropy: 0.1153 - val_loss: 0.4085 - val_acc: 0.8723 - val_binary_crossentropy: 0.3422
# Epoch 9/20
#  - 6s - loss: 0.1728 - acc: 0.9664 - binary_crossentropy: 0.1058 - val_loss: 0.4255 - val_acc: 0.8696 - val_binary_crossentropy: 0.3576
# Epoch 10/20
#  - 5s - loss: 0.1667 - acc: 0.9696 - binary_crossentropy: 0.0981 - val_loss: 0.4406 - val_acc: 0.8673 - val_binary_crossentropy: 0.3714
# Epoch 11/20
#  - 6s - loss: 0.1597 - acc: 0.9717 - binary_crossentropy: 0.0898 - val_loss: 0.4502 - val_acc: 0.8668 - val_binary_crossentropy: 0.3795
# Epoch 12/20
#  - 7s - loss: 0.1528 - acc: 0.9757 - binary_crossentropy: 0.0820 - val_loss: 0.4685 - val_acc: 0.8636 - val_binary_crossentropy: 0.3973
# Epoch 13/20
#  - 6s - loss: 0.1479 - acc: 0.9788 - binary_crossentropy: 0.0760 - val_loss: 0.4762 - val_acc: 0.8631 - val_binary_crossentropy: 0.4040
# Epoch 14/20
#  - 5s - loss: 0.1381 - acc: 0.9826 - binary_crossentropy: 0.0661 - val_loss: 0.4835 - val_acc: 0.8643 - val_binary_crossentropy: 0.4117
# Epoch 15/20
#  - 5s - loss: 0.1306 - acc: 0.9860 - binary_crossentropy: 0.0591 - val_loss: 0.4983 - val_acc: 0.8611 - val_binary_crossentropy: 0.4270
# Epoch 16/20
#  - 6s - loss: 0.1272 - acc: 0.9873 - binary_crossentropy: 0.0557 - val_loss: 0.5063 - val_acc: 0.8599 - val_binary_crossentropy: 0.4346
# Epoch 17/20
#  - 5s - loss: 0.1232 - acc: 0.9889 - binary_crossentropy: 0.0517 - val_loss: 0.5153 - val_acc: 0.8616 - val_binary_crossentropy: 0.4437
# Epoch 18/20
#  - 7s - loss: 0.1204 - acc: 0.9888 - binary_crossentropy: 0.0488 - val_loss: 0.5377 - val_acc: 0.8570 - val_binary_crossentropy: 0.4659
# Epoch 19/20
#  - 8s - loss: 0.1169 - acc: 0.9908 - binary_crossentropy: 0.0452 - val_loss: 0.5283 - val_acc: 0.8613 - val_binary_crossentropy: 0.4568
# Epoch 20/20
#  - 5s - loss: 0.1139 - acc: 0.9912 - binary_crossentropy: 0.0426 - val_loss: 0.5443 - val_acc: 0.8583 - val_binary_crossentropy: 0.4728

# %%
plot_history([('baseline', baseline_history), 
             ('L2', l2_model_history)])

# %%
# Adding dropout

dpt_model = keras.Sequential([
    keras.layers.Dense(16, activation = tf.nn.relu, input_shape = (NUM_WORDS, )),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation = tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation = tf.nn.sigmoid)
])

dpt_model.compile(optimizer = 'adam',
                 loss = 'binary_crossentropy',
                 metrics = ['accuracy', 'binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels, epochs = 20, 
                                 batch_size = 512, validation_data = (test_data, test_labels),
                                 verbose = 2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 11s - loss: 0.6544 - acc: 0.6026 - binary_crossentropy: 0.6544 - val_loss: 0.5641 - val_acc: 0.8438 - val_binary_crossentropy: 0.5641
# Epoch 2/20
#  - 5s - loss: 0.5133 - acc: 0.7795 - binary_crossentropy: 0.5133 - val_loss: 0.3981 - val_acc: 0.8778 - val_binary_crossentropy: 0.3981
# Epoch 3/20
